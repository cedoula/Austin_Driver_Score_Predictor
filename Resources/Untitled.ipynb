# %%
import pandas as pd

# %%
df = pd.read_csv("mock_data.csv")

# %%
pd.set_option("display.max_columns",100)

# %%
df.head()
# Out:
#    Crash Death Count   Crash Severity  Crash Time  Crash Total Injury Count  \
# 0                  0  N - NOT INJURED        1111                         0
# 1                  0  N - NOT INJURED          36                         0
# 2                  0  N - NOT INJURED          36                         0
# 3                  0  N - NOT INJURED          36                         0
# 4                  0  N - NOT INJURED         728                         0
#
#    Crash Year Day of Week Highway Number  Highway System     Latitude  \
# 0        2018      MONDAY        No Data         No Data  30.20098162
# 1        2018      MONDAY            734  FARM TO MARKET  30.36856269
# 2        2018      MONDAY            734  FARM TO MARKET  30.36856269
# 3        2018      MONDAY            734  FARM TO MARKET  30.36856269
# 4        2018      MONDAY            734  FARM TO MARKET  30.40533278
#
#          Light Condition     Longitude Surface Condition Surface Type  \
# 0           1 - DAYLIGHT  -97.87090786           1 - DRY      No Data
# 1      3 - DARK, LIGHTED  -97.61329002           1 - DRY      No Data
# 2      3 - DARK, LIGHTED  -97.61329002           1 - DRY      No Data
# 3      3 - DARK, LIGHTED  -97.61329002           1 - DRY      No Data
# 4  2 - DARK, NOT LIGHTED  -97.66431513           1 - DRY      No Data
#
#   Weather Condition          Vehicle Body Style  \
# 0         1 - CLEAR                    VN - VAN
# 1         1 - CLEAR  P4 - PASSENGER CAR, 4-DOOR
# 2         1 - CLEAR  P4 - PASSENGER CAR, 4-DOOR
# 3         1 - CLEAR  P4 - PASSENGER CAR, 4-DOOR
# 4        2 - CLOUDY  P4 - PASSENGER CAR, 4-DOOR
#
#   Vehicle Damage Rating 1 - Severity Vehicle Damage Rating 2 - Severity  \
# 0                      3 - DAMAGED 3                            No Data
# 1              7 - DAMAGED 7 HIGHEST                            No Data
# 2                      6 - DAMAGED 6                            No Data
# 3                      6 - DAMAGED 6                            No Data
# 4                      3 - DAMAGED 3                            No Data
#
#   Vehicle Make  Vehicle Model Name Vehicle Model Year   Citation Person Age  \
# 0        HONDA     ODYSSEY (HONDA)               2005    No Data         34
# 1        HONDA       CIVIC (HONDA)               2013  E16001834         49
# 2      HYUNDAI  SANTA FE (HYUNDAI)               2011    No Data         22
# 3      HYUNDAI  SANTA FE (HYUNDAI)               2011    No Data         48
# 4     CHRYSLER      300 (CHRYSLER)               2006    No Data         21
#
#   Person Alcohol Result Person Drug Test Result Person Gender  \
# 0               No Data     97 - NOT APPLICABLE    2 - FEMALE
# 1               No Data     97 - NOT APPLICABLE    2 - FEMALE
# 2               No Data     97 - NOT APPLICABLE    2 - FEMALE
# 3               No Data                 No Data    2 - FEMALE
# 4               No Data     97 - NOT APPLICABLE      1 - MALE
#
#   Person Injury Severity             Person Type
# 0        N - NOT INJURED              1 - DRIVER
# 1        N - NOT INJURED              1 - DRIVER
# 2        N - NOT INJURED              1 - DRIVER
# 3        N - NOT INJURED  2 - PASSENGER/OCCUPANT
# 4        N - NOT INJURED              1 - DRIVER

# %%
df = df.reset_index()

# %%
newdf= df.rename(columns= {'index': "ID"})
newdf
# Out:
#             ID  Crash Death Count       Crash Severity  Crash Time  \
# 0            0                  0      N - NOT INJURED        1111
# 1            1                  0      N - NOT INJURED          36
# 2            2                  0      N - NOT INJURED          36
# 3            3                  0      N - NOT INJURED          36
# 4            4                  0      N - NOT INJURED         728
# ...        ...                ...                  ...         ...
# 119098  119098                  0  C - POSSIBLE INJURY        1015
# 119099  119099                  0  C - POSSIBLE INJURY        1015
# 119100  119100                  0      N - NOT INJURED        1118
# 119101  119101                  0      N - NOT INJURED        1118
# 119102  119102                  0      N - NOT INJURED        1118
#
#         Crash Total Injury Count  Crash Year Day of Week Highway Number  \
# 0                              0        2018      MONDAY        No Data
# 1                              0        2018      MONDAY            734
# 2                              0        2018      MONDAY            734
# 3                              0        2018      MONDAY            734
# 4                              0        2018      MONDAY            734
# ...                          ...         ...         ...            ...
# 119098                         1        2020     TUESDAY        No Data
# 119099                         1        2020     TUESDAY        No Data
# 119100                         0        2020     TUESDAY        No Data
# 119101                         0        2020     TUESDAY        No Data
# 119102                         0        2020     TUESDAY        No Data
#
#         Highway System     Latitude        Light Condition     Longitude  \
# 0              No Data  30.20098162           1 - DAYLIGHT  -97.87090786
# 1       FARM TO MARKET  30.36856269      3 - DARK, LIGHTED  -97.61329002
# 2       FARM TO MARKET  30.36856269      3 - DARK, LIGHTED  -97.61329002
# 3       FARM TO MARKET  30.36856269      3 - DARK, LIGHTED  -97.61329002
# 4       FARM TO MARKET  30.40533278  2 - DARK, NOT LIGHTED  -97.66431513
# ...                ...          ...                    ...           ...
# 119098         No Data  30.35237476           1 - DAYLIGHT  -97.75114246
# 119099         No Data  30.35237476           1 - DAYLIGHT  -97.75114246
# 119100         No Data  30.28755477           1 - DAYLIGHT  -97.70702247
# 119101         No Data  30.28755477           1 - DAYLIGHT  -97.70702247
# 119102         No Data  30.28755477           1 - DAYLIGHT  -97.70702247
#
#        Surface Condition Surface Type Weather Condition  \
# 0                1 - DRY      No Data         1 - CLEAR
# 1                1 - DRY      No Data         1 - CLEAR
# 2                1 - DRY      No Data         1 - CLEAR
# 3                1 - DRY      No Data         1 - CLEAR
# 4                1 - DRY      No Data        2 - CLOUDY
# ...                  ...          ...               ...
# 119098           1 - DRY      No Data        2 - CLOUDY
# 119099           1 - DRY      No Data        2 - CLOUDY
# 119100           1 - DRY      No Data        2 - CLOUDY
# 119101           1 - DRY      No Data        2 - CLOUDY
# 119102           1 - DRY      No Data        2 - CLOUDY
#
#                 Vehicle Body Style Vehicle Damage Rating 1 - Severity  \
# 0                         VN - VAN                      3 - DAMAGED 3
# 1       P4 - PASSENGER CAR, 4-DOOR              7 - DAMAGED 7 HIGHEST
# 2       P4 - PASSENGER CAR, 4-DOOR                      6 - DAMAGED 6
# 3       P4 - PASSENGER CAR, 4-DOOR                      6 - DAMAGED 6
# 4       P4 - PASSENGER CAR, 4-DOOR                      3 - DAMAGED 3
# ...                            ...                                ...
# 119098  P4 - PASSENGER CAR, 4-DOOR                      4 - DAMAGED 4
# 119099  P4 - PASSENGER CAR, 4-DOOR                      5 - DAMAGED 5
# 119100  P4 - PASSENGER CAR, 4-DOOR                      4 - DAMAGED 4
# 119101  P4 - PASSENGER CAR, 4-DOOR                      4 - DAMAGED 4
# 119102  P4 - PASSENGER CAR, 4-DOOR                      4 - DAMAGED 4
#
#        Vehicle Damage Rating 2 - Severity Vehicle Make  Vehicle Model Name  \
# 0                                 No Data        HONDA     ODYSSEY (HONDA)
# 1                                 No Data        HONDA       CIVIC (HONDA)
# 2                                 No Data      HYUNDAI  SANTA FE (HYUNDAI)
# 3                                 No Data      HYUNDAI  SANTA FE (HYUNDAI)
# 4                                 No Data     CHRYSLER      300 (CHRYSLER)
# ...                                   ...          ...                 ...
# 119098                            No Data        LEXUS      ES 300 (LEXUS)
# 119099                            No Data       TOYOTA      CAMRY (TOYOTA)
# 119100                            No Data      HYUNDAI    SONATA (HYUNDAI)
# 119101                            No Data         FORD       ESCAPE (FORD)
# 119102                            No Data         FORD       ESCAPE (FORD)
#
#        Vehicle Model Year              Citation Person Age  \
# 0                    2005               No Data         34
# 1                    2013             E16001834         49
# 2                    2011               No Data         22
# 3                    2011               No Data         48
# 4                    2006               No Data         21
# ...                   ...                   ...        ...
# 119098               2000               No Data         94
# 119099               2011               No Data         39
# 119100               2011  E17305749, E17305749         31
# 119101               2013               No Data         32
# 119102               2013               No Data          0
#
#        Person Alcohol Result Person Drug Test Result Person Gender  \
# 0                    No Data     97 - NOT APPLICABLE    2 - FEMALE
# 1                    No Data     97 - NOT APPLICABLE    2 - FEMALE
# 2                    No Data     97 - NOT APPLICABLE    2 - FEMALE
# 3                    No Data                 No Data    2 - FEMALE
# 4                    No Data     97 - NOT APPLICABLE      1 - MALE
# ...                      ...                     ...           ...
# 119098               No Data                 No Data      1 - MALE
# 119099               No Data     97 - NOT APPLICABLE      1 - MALE
# 119100               No Data     97 - NOT APPLICABLE      1 - MALE
# 119101               No Data     97 - NOT APPLICABLE      1 - MALE
# 119102               No Data                 No Data    2 - FEMALE
#
#        Person Injury Severity             Person Type
# 0             N - NOT INJURED              1 - DRIVER
# 1             N - NOT INJURED              1 - DRIVER
# 2             N - NOT INJURED              1 - DRIVER
# 3             N - NOT INJURED  2 - PASSENGER/OCCUPANT
# 4             N - NOT INJURED              1 - DRIVER
# ...                       ...                     ...
# 119098        N - NOT INJURED  2 - PASSENGER/OCCUPANT
# 119099        N - NOT INJURED              1 - DRIVER
# 119100        N - NOT INJURED              1 - DRIVER
# 119101        N - NOT INJURED              1 - DRIVER
# 119102        N - NOT INJURED  2 - PASSENGER/OCCUPANT
#
# [119103 rows x 28 columns]

# %%
internal_df= newdf[['ID','Crash Time', 'Crash Death Count', 'Crash Severity', 'Crash Total Injury Count', 'Crash Year', 'Vehicle Body Style', 'Vehicle Damage Rating 1 - Severity','Vehicle Damage Rating 2 - Severity', 'Vehicle Make', 'Vehicle Model Name', 'Vehicle Model Year', 'Citation', 'Person Age', 'Person Alcohol Result', 'Person Drug Test Result', 'Person Gender', 'Person Injury Severity' , 'Person Type']]
internal_df
# Out:
#             ID  Crash Time  Crash Death Count       Crash Severity  \
# 0            0        1111                  0      N - NOT INJURED
# 1            1          36                  0      N - NOT INJURED
# 2            2          36                  0      N - NOT INJURED
# 3            3          36                  0      N - NOT INJURED
# 4            4         728                  0      N - NOT INJURED
# ...        ...         ...                ...                  ...
# 119098  119098        1015                  0  C - POSSIBLE INJURY
# 119099  119099        1015                  0  C - POSSIBLE INJURY
# 119100  119100        1118                  0      N - NOT INJURED
# 119101  119101        1118                  0      N - NOT INJURED
# 119102  119102        1118                  0      N - NOT INJURED
#
#         Crash Total Injury Count  Crash Year          Vehicle Body Style  \
# 0                              0        2018                    VN - VAN
# 1                              0        2018  P4 - PASSENGER CAR, 4-DOOR
# 2                              0        2018  P4 - PASSENGER CAR, 4-DOOR
# 3                              0        2018  P4 - PASSENGER CAR, 4-DOOR
# 4                              0        2018  P4 - PASSENGER CAR, 4-DOOR
# ...                          ...         ...                         ...
# 119098                         1        2020  P4 - PASSENGER CAR, 4-DOOR
# 119099                         1        2020  P4 - PASSENGER CAR, 4-DOOR
# 119100                         0        2020  P4 - PASSENGER CAR, 4-DOOR
# 119101                         0        2020  P4 - PASSENGER CAR, 4-DOOR
# 119102                         0        2020  P4 - PASSENGER CAR, 4-DOOR
#
#        Vehicle Damage Rating 1 - Severity Vehicle Damage Rating 2 - Severity  \
# 0                           3 - DAMAGED 3                            No Data
# 1                   7 - DAMAGED 7 HIGHEST                            No Data
# 2                           6 - DAMAGED 6                            No Data
# 3                           6 - DAMAGED 6                            No Data
# 4                           3 - DAMAGED 3                            No Data
# ...                                   ...                                ...
# 119098                      4 - DAMAGED 4                            No Data
# 119099                      5 - DAMAGED 5                            No Data
# 119100                      4 - DAMAGED 4                            No Data
# 119101                      4 - DAMAGED 4                            No Data
# 119102                      4 - DAMAGED 4                            No Data
#
#        Vehicle Make  Vehicle Model Name Vehicle Model Year  \
# 0             HONDA     ODYSSEY (HONDA)               2005
# 1             HONDA       CIVIC (HONDA)               2013
# 2           HYUNDAI  SANTA FE (HYUNDAI)               2011
# 3           HYUNDAI  SANTA FE (HYUNDAI)               2011
# 4          CHRYSLER      300 (CHRYSLER)               2006
# ...             ...                 ...                ...
# 119098        LEXUS      ES 300 (LEXUS)               2000
# 119099       TOYOTA      CAMRY (TOYOTA)               2011
# 119100      HYUNDAI    SONATA (HYUNDAI)               2011
# 119101         FORD       ESCAPE (FORD)               2013
# 119102         FORD       ESCAPE (FORD)               2013
#
#                     Citation Person Age Person Alcohol Result  \
# 0                    No Data         34               No Data
# 1                  E16001834         49               No Data
# 2                    No Data         22               No Data
# 3                    No Data         48               No Data
# 4                    No Data         21               No Data
# ...                      ...        ...                   ...
# 119098               No Data         94               No Data
# 119099               No Data         39               No Data
# 119100  E17305749, E17305749         31               No Data
# 119101               No Data         32               No Data
# 119102               No Data          0               No Data
#
#        Person Drug Test Result Person Gender Person Injury Severity  \
# 0          97 - NOT APPLICABLE    2 - FEMALE        N - NOT INJURED
# 1          97 - NOT APPLICABLE    2 - FEMALE        N - NOT INJURED
# 2          97 - NOT APPLICABLE    2 - FEMALE        N - NOT INJURED
# 3                      No Data    2 - FEMALE        N - NOT INJURED
# 4          97 - NOT APPLICABLE      1 - MALE        N - NOT INJURED
# ...                        ...           ...                    ...
# 119098                 No Data      1 - MALE        N - NOT INJURED
# 119099     97 - NOT APPLICABLE      1 - MALE        N - NOT INJURED
# 119100     97 - NOT APPLICABLE      1 - MALE        N - NOT INJURED
# 119101     97 - NOT APPLICABLE      1 - MALE        N - NOT INJURED
# 119102                 No Data    2 - FEMALE        N - NOT INJURED
#
#                    Person Type
# 0                   1 - DRIVER
# 1                   1 - DRIVER
# 2                   1 - DRIVER
# 3       2 - PASSENGER/OCCUPANT
# 4                   1 - DRIVER
# ...                        ...
# 119098  2 - PASSENGER/OCCUPANT
# 119099              1 - DRIVER
# 119100              1 - DRIVER
# 119101              1 - DRIVER
# 119102  2 - PASSENGER/OCCUPANT
#
# [119103 rows x 19 columns]

# %%
external_df= newdf[['ID', 'Crash Year', 'Day of Week', 'Highway Number', 'Highway System', 'Latitude', 'Light Condition', 'Longitude', 'Surface Condition', 'Surface Type', 'Weather Condition']]
external_df
# Out:
#             ID  Crash Year Day of Week Highway Number  Highway System  \
# 0            0        2018      MONDAY        No Data         No Data
# 1            1        2018      MONDAY            734  FARM TO MARKET
# 2            2        2018      MONDAY            734  FARM TO MARKET
# 3            3        2018      MONDAY            734  FARM TO MARKET
# 4            4        2018      MONDAY            734  FARM TO MARKET
# ...        ...         ...         ...            ...             ...
# 119098  119098        2020     TUESDAY        No Data         No Data
# 119099  119099        2020     TUESDAY        No Data         No Data
# 119100  119100        2020     TUESDAY        No Data         No Data
# 119101  119101        2020     TUESDAY        No Data         No Data
# 119102  119102        2020     TUESDAY        No Data         No Data
#
#            Latitude        Light Condition     Longitude Surface Condition  \
# 0       30.20098162           1 - DAYLIGHT  -97.87090786           1 - DRY
# 1       30.36856269      3 - DARK, LIGHTED  -97.61329002           1 - DRY
# 2       30.36856269      3 - DARK, LIGHTED  -97.61329002           1 - DRY
# 3       30.36856269      3 - DARK, LIGHTED  -97.61329002           1 - DRY
# 4       30.40533278  2 - DARK, NOT LIGHTED  -97.66431513           1 - DRY
# ...             ...                    ...           ...               ...
# 119098  30.35237476           1 - DAYLIGHT  -97.75114246           1 - DRY
# 119099  30.35237476           1 - DAYLIGHT  -97.75114246           1 - DRY
# 119100  30.28755477           1 - DAYLIGHT  -97.70702247           1 - DRY
# 119101  30.28755477           1 - DAYLIGHT  -97.70702247           1 - DRY
# 119102  30.28755477           1 - DAYLIGHT  -97.70702247           1 - DRY
#
#        Surface Type Weather Condition
# 0           No Data         1 - CLEAR
# 1           No Data         1 - CLEAR
# 2           No Data         1 - CLEAR
# 3           No Data         1 - CLEAR
# 4           No Data        2 - CLOUDY
# ...             ...               ...
# 119098      No Data        2 - CLOUDY
# 119099      No Data        2 - CLOUDY
# 119100      No Data        2 - CLOUDY
# 119101      No Data        2 - CLOUDY
# 119102      No Data        2 - CLOUDY
#
# [119103 rows x 11 columns]

# %%
external_df = external_df.drop(columns = "Surface Type")

# %%
external_df
# Out:
#             ID  Crash Year Day of Week Highway Number  Highway System  \
# 0            0        2018      MONDAY        No Data         No Data
# 1            1        2018      MONDAY            734  FARM TO MARKET
# 2            2        2018      MONDAY            734  FARM TO MARKET
# 3            3        2018      MONDAY            734  FARM TO MARKET
# 4            4        2018      MONDAY            734  FARM TO MARKET
# ...        ...         ...         ...            ...             ...
# 119098  119098        2020     TUESDAY        No Data         No Data
# 119099  119099        2020     TUESDAY        No Data         No Data
# 119100  119100        2020     TUESDAY        No Data         No Data
# 119101  119101        2020     TUESDAY        No Data         No Data
# 119102  119102        2020     TUESDAY        No Data         No Data
#
#            Latitude        Light Condition     Longitude Surface Condition  \
# 0       30.20098162           1 - DAYLIGHT  -97.87090786           1 - DRY
# 1       30.36856269      3 - DARK, LIGHTED  -97.61329002           1 - DRY
# 2       30.36856269      3 - DARK, LIGHTED  -97.61329002           1 - DRY
# 3       30.36856269      3 - DARK, LIGHTED  -97.61329002           1 - DRY
# 4       30.40533278  2 - DARK, NOT LIGHTED  -97.66431513           1 - DRY
# ...             ...                    ...           ...               ...
# 119098  30.35237476           1 - DAYLIGHT  -97.75114246           1 - DRY
# 119099  30.35237476           1 - DAYLIGHT  -97.75114246           1 - DRY
# 119100  30.28755477           1 - DAYLIGHT  -97.70702247           1 - DRY
# 119101  30.28755477           1 - DAYLIGHT  -97.70702247           1 - DRY
# 119102  30.28755477           1 - DAYLIGHT  -97.70702247           1 - DRY
#
#        Weather Condition
# 0              1 - CLEAR
# 1              1 - CLEAR
# 2              1 - CLEAR
# 3              1 - CLEAR
# 4             2 - CLOUDY
# ...                  ...
# 119098        2 - CLOUDY
# 119099        2 - CLOUDY
# 119100        2 - CLOUDY
# 119101        2 - CLOUDY
# 119102        2 - CLOUDY
#
# [119103 rows x 10 columns]

# %%
df.to_csv("crash_data.csv")

# %%
import csv_to_sqlite 

# all the usual options are supported
options = csv_to_sqlite.CsvOptions(typing_style="full", encoding="windows-1250") 
input_files = ["crash_data.csv] # pass in a list of CSV files
csv_to_sqlite.write_csv(input_files, "output.sqlite", options)
# Out:
#   File "<ipython-input-16-3ccf6fc9dabc>", line 5
#     input_files = ["crash_data.csv] # pass in a list of CSV files
#                                                                  ^
# SyntaxError: EOL while scanning string literal
